# %%
from PIL import Image
import os

PAGE_IMAGES_FOLDER = "D:\OCR session"

# %%
# %pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.11.4 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from scikit-image) (1.15.3)
# Requirement already satisfied: networkx>=3.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from scikit-image) (11.3.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from scikit-image) (2025.5.10)
# Requirement already satisfied: packaging>=21 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from scikit-image) (0.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ---
# ## Tilt correction
#
# ---

# %%
import cv2
import numpy as np
from skimage.transform import hough_line, hough_line_peaks
from skimage.feature import canny

WATERMARK_THRESHOLD_LOW = 175
WATERMARK_THRESHOLD_HIGH = 250

# Model for orientation skew correction
EAST_MODEL = "frozen_east_text_detection.pb"
ANGLE_TOLLERANCE = 0.25
MIN_CONFIDENCE = 0.5
MARGIN_TOLLERANCE = 9
EAST_WIDTH = 1280
EAST_HEIGHT = 1280
ALIGN = False
ALIGN_MODE = 'FAST'

class Orientation:

    def __init__(self, image, file_properties, conf_threshold=50, lang='eng'):

        # self.image_path     = image_path
        self.image = image
        self.file_properties = file_properties
        # self.lines          = lines
        self.conf_threshold = int(conf_threshold)

        self.timer = {'net': 0, 'restore': 0, 'nms': 0}
        self.text = {}
        self.lang = lang

        # self.re_orient()

    def rotate_bound(self, image, angle):
        # grab the dimensions of the image and then determine the
        # center
        (h, w) = image.shape[:2]
        (cX, cY) = (w / 2, h / 2)

        # grab the rotation matrix (applying the negative of the
        # angle to rotate clockwise), then grab the sine and cosine
        # (i.e., the rotation components of the matrix)
        M = cv2.getRotationMatrix2D((cX, cY), -angle, 1.0)
        cos = np.abs(M[0, 0])
        sin = np.abs(M[0, 1])

        # compute the new bounding dimensions of the image
        nW = int((h * sin) + (w * cos))
        nH = int((h * cos) + (w * sin))

        # adjust the rotation matrix to take into account translation
        M[0, 2] += (nW / 2) - cX
        M[1, 2] += (nH / 2) - cY

        # perform the actual rotation and return the image
        return cv2.warpAffine(image, M, (nW, nH), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)

    def east_detect(self, image, args):

        # orig = image.copy()
        (H, W) = image.shape[:2]

        (newW, newH) = (args["width"], args["height"])
        rW = W / float(newW)
        rH = H / float(newH)

        image = cv2.resize(image, (newW, newH))
        (H, W) = image.shape[:2]

        layerNames = [
            "feature_fusion/Conv_7/Sigmoid",
            "feature_fusion/concat_3"]

        # print("[INFO] loading EAST text detector...")
        net = cv2.dnn.readNet(args["east"])

        blob = cv2.dnn.blobFromImage(image, 1.0, (W, H),
                                     (123.68, 116.78, 103.94), swapRB=True, crop=False)
        # start = time.time()
        net.setInput(blob)
        (scores, geometry) = net.forward(layerNames)
        # end = time.time()

        # print("[INFO] text detection took {:.6f} seconds".format(end - start))

        # confidence scores
        (numRows, numCols) = scores.shape[2:4]
        angl = []

        for y in range(0, numRows):

            scoresData = scores[0, 0, y]
            anglesData = geometry[0, 4, y]

            for x in range(0, numCols):
                if scoresData[x] < args["min_confidence"]:
                    continue

                angle = anglesData[x]
                angl.append(angle*180/(np.pi))

        return np.median(angl)

    def east(self, image, args):

        # image = cv2.imread(image_path)
        angle = Orientation.east_detect(self, image, args)
        # print("angle*********",angle)

        return image, angle

    def hough_transforms(self, image):

        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        thresh = cv2.GaussianBlur(gray, (11, 11), 0)
        edges = canny(thresh)
        tested_angles = np.deg2rad(np.arange(0.1, 180.0))
        h, theta, d = hough_line(edges, theta=tested_angles)
        accum, angles, dists = hough_line_peaks(h, theta, d)

        return accum, angles, dists

    def east_hough_line(self, image, args):
        image, angle = Orientation.east(self, image, args)
        h, theta, d = Orientation.hough_transforms(self, image)
        theta = np.rad2deg(np.pi/2-theta)
        # theta = np.rad2deg(theta-np.pi/2)
        margin = args['margin_tollerance']
        low_thresh = angle-margin
        high_thresh = angle+margin
        filter_theta = theta[theta > low_thresh]
        filter_theta = filter_theta[filter_theta < high_thresh]

        return image, np.median(filter_theta)

    def re_orient_east(self):
        lang = 'hi'

        args = {
            "image": self.image,
            "east": EAST_MODEL,
            "min_confidence": MIN_CONFIDENCE,
            "margin_tollerance": MARGIN_TOLLERANCE,
            "width": EAST_WIDTH,
            "height": EAST_HEIGHT
        }

        image, angle = Orientation.east_hough_line(self, args['image'], args)

        if abs(angle) > ANGLE_TOLLERANCE:
            image = Orientation.rotate_bound(self, image, angle)
            # print(self.image_path)
            # image_path = Orientation(self.image_path)
            # cv2.imwrite(f'{self.image_path}', image)

        print("Angle detectd is  {} ".format(angle))

        return image, angle

# %%
# %pip install doclayout-yolo
# Out:
# Requirement already satisfied: doclayout-yolo in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (0.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\asus\appdata\roaming\python\python310\site-packages (from doclayout-yolo) (3.10.6)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from doclayout-yolo) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from doclayout-yolo) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from doclayout-yolo) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from doclayout-yolo) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from doclayout-yolo) (1.15.3)
# Requirement already satisfied: torch>=2.0.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from doclayout-yolo) (2.2.0+cpu)
# Requirement already satisfied: torchvision>=0.15.2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from doclayout-yolo) (0.17.0+cpu)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from doclayout-yolo) (4.67.1)
# Requirement already satisfied: psutil in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from doclayout-yolo) (7.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from doclayout-yolo) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in c:\users\asus\appdata\roaming\python\python310\site-packages (from doclayout-yolo) (0.1.1.post2209072238)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from doclayout-yolo) (2.3.2)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\asus\appdata\roaming\python\python310\site-packages (from doclayout-yolo) (0.13.2)
# Requirement already satisfied: albumentations>=1.4.11 in c:\users\asus\appdata\roaming\python\python310\site-packages (from doclayout-yolo) (2.0.8)
# Requirement already satisfied: numpy>=1.24.4 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from albumentations>=1.4.11->doclayout-yolo) (1.26.4)
# Requirement already satisfied: pydantic>=2.9.2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from albumentations>=1.4.11->doclayout-yolo) (2.11.7)
# Requirement already satisfied: albucore==0.0.24 in c:\users\asus\appdata\roaming\python\python310\site-packages (from albumentations>=1.4.11->doclayout-yolo) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from albumentations>=1.4.11->doclayout-yolo) (4.10.0.84)
# Requirement already satisfied: stringzilla>=3.10.4 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from albucore==0.0.24->albumentations>=1.4.11->doclayout-yolo) (4.0.0)
# Requirement already satisfied: simsimd>=5.9.2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from albucore==0.0.24->albumentations>=1.4.11->doclayout-yolo) (6.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->doclayout-yolo) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->doclayout-yolo) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->doclayout-yolo) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->doclayout-yolo) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->doclayout-yolo) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->doclayout-yolo) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.3.0->doclayout-yolo) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.1.4->doclayout-yolo) (2022.7.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.1.4->doclayout-yolo) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=2.9.2->albumentations>=1.4.11->doclayout-yolo) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=2.9.2->albumentations>=1.4.11->doclayout-yolo) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=2.9.2->albumentations>=1.4.11->doclayout-yolo) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=2.9.2->albumentations>=1.4.11->doclayout-yolo) (0.4.1)
# Requirement already satisfied: six>=1.5 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->doclayout-yolo) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->doclayout-yolo) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->doclayout-yolo) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->doclayout-yolo) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.23.0->doclayout-yolo) (2025.8.3)
# Requirement already satisfied: filelock in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch>=2.0.1->doclayout-yolo) (3.19.1)
# Requirement already satisfied: sympy in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch>=2.0.1->doclayout-yolo) (1.14.0)
# Requirement already satisfied: networkx in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch>=2.0.1->doclayout-yolo) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch>=2.0.1->doclayout-yolo) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from torch>=2.0.1->doclayout-yolo) (2025.9.0)
# Requirement already satisfied: colorama in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.64.0->doclayout-yolo) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from jinja2->torch>=2.0.1->doclayout-yolo) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\asus\appdata\local\programs\python\python310\lib\site-packages (from sympy->torch>=2.0.1->doclayout-yolo) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip show doclayout-yolo
# Out:
# Name: doclayout_yolo
# Version: 0.0.2
# Summary: DocLayout-YOLO: an effecient and robust document layout analysis method.
# Home-page:
# Author: Zhiyuan Zhao, Hengrui Kang, Bin Wang, Conghui He
# Author-email:
# License: AGPL-3.0
# Location: c:\users\asus\appdata\local\programs\python\python310\lib\site-packages
# Requires: albumentations, matplotlib, opencv-python, pandas, pillow, psutil, py-cpuinfo, pyyaml, requests, scipy, seaborn, thop, torch, torchvision, tqdm
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

model_path = r"D:\OCR\Pipeline\yolov12l-doclaynet.pt"
model = YOLO(model_path)

# %% [markdown]
# ---
# ## Layout detection
#
# ---

# %%
from PIL import Image, ImageOps
import os
import numpy as np
import cv2
from collections import Counter, defaultdict
from skimage.transform import hough_line, hough_line_peaks
from skimage.feature import canny
from doclayout_yolo import YOLOv10  # Ensure doclayout-yolo is installed

# ---------- Model Setup ----------
model_path = r"D:\OCR\Pipeline\yolov12l-doclaynet.pt"
model = YOLO(model_path)

def iou(box1, box2):
    x1, y1, x2, y2 = box1
    x1_p, y1_p, x2_p, y2_p = box2
    xi1, yi1 = max(x1, x1_p), max(y1, y1_p)
    xi2, yi2 = min(x2, x2_p), min(y2, y2_p)
    iw = max(0.0, xi2 - xi1)
    ih = max(0.0, yi2 - yi1)
    inter = iw * ih
    area1 = max(0.0, (x2 - x1) * (y2 - y1))
    area2 = max(0.0, (x2_p - x1_p) * (y2_p - y1_p))
    union = area1 + area2 - inter
    return inter / union if union > 0 else 0.0

def perform_prediction(image, model, imgsz=1024, conf=0.4, iou=0.45, device="cpu"):
    return model.predict(image, imgsz=imgsz, conf=conf, iou=iou, device=device)

def extract_bboxes(det_res_list):
    boxes_info = []
    for result in det_res_list:
        names = result.names
        for box in result.boxes:
            x1, y1, x2, y2 = box.xyxy[0].tolist()
            label_idx = int(box.cls.item())
            confidence = float(box.conf.item())
            label = names.get(label_idx, str(label_idx))
            boxes_info.append({"bbox": [x1, y1, x2, y2], "label": label, "confidence": confidence})
    return boxes_info

def nms_classwise(boxes, iou_thresh=0.3):  # Less aggressive
    out = []
    labels = set([b["label"] for b in boxes])
    for label in labels:
        group = [b for b in boxes if b["label"] == label]
        group = sorted(group, key=lambda x: x["confidence"], reverse=True)
        keep = []
        suppressed = [False] * len(group)
        for i in range(len(group)):
            if suppressed[i]:
                continue
            keep.append(group[i])
            for j in range(i + 1, len(group)):
                if suppressed[j]:
                    continue
                if iou(group[i]["bbox"], group[j]["bbox"]) > iou_thresh:
                    suppressed[j] = True
        out.extend(keep)
    return out

def deduplicate_boxes(boxes, iou_thresh=0.2):  # Less aggressive
    out = []
    labels = set([b["label"] for b in boxes])
    for label in labels:
        group = [b for b in boxes if b["label"] == label]
        group = sorted(group, key=lambda x: x["confidence"], reverse=True)
        keep = []
        while group:
            ref = group.pop(0)
            keep.append(ref)
            group = [g for g in group if iou(ref["bbox"], g["bbox"]) < iou_thresh]
        out.extend(keep)
    return out

def merge_text_boxes(boxes, merge_iou=0.1):  # Only mildly merge
    text_boxes = [b for b in boxes if b["label"].lower() == "text"]
    other_boxes = [b for b in boxes if b["label"].lower() != "text"]
    if not text_boxes:
        return boxes
    used = [False] * len(text_boxes)
    merged = []
    for i in range(len(text_boxes)):
        if used[i]:
            continue
        bx = text_boxes[i]["bbox"].copy()
        conf = text_boxes[i]["confidence"]
        used[i] = True
        for j in range(i+1, len(text_boxes)):
            if used[j]:
                continue
            if iou(bx, text_boxes[j]["bbox"]) >= merge_iou:
                bx = [
                    min(bx[0], text_boxes[j]["bbox"][0]),
                    min(bx[1], text_boxes[j]["bbox"][1]),
                    max(bx[2], text_boxes[j]["bbox"][2]),
                    max(bx[3], text_boxes[j]["bbox"][3]),
                ]
                conf = max(conf, text_boxes[j]["confidence"])
                used[j] = True
        merged.append({"bbox": bx, "label": "Text", "confidence": conf})
    return other_boxes + merged

def resolve_cross_class_conflicts(boxes, cross_iou_thresh=0.9999, class_priority=None):
    if class_priority is None:
        class_priority = defaultdict(lambda: 0)
        class_priority.update({"Text": 6, "Table": 5, "Picture": 4,
                              "Section-header": 3, "List-item": 2, "Caption": 1})
    boxes_sorted = sorted(boxes, key=lambda x: x["confidence"], reverse=True)
    keep = []
    removed = [False] * len(boxes_sorted)
    for i in range(len(boxes_sorted)):
        if removed[i]:
            continue
        a = boxes_sorted[i]
        keep.append(a)
        for j in range(i+1, len(boxes_sorted)):
            if removed[j]:
                continue
            b = boxes_sorted[j]
            pair_iou = iou(a["bbox"], b["bbox"])
            if pair_iou >= cross_iou_thresh:
                if b["confidence"] > a["confidence"]:
                    keep[-1] = b
                    removed[i] = True
                    removed[j] = True
                elif abs(b["confidence"] - a["confidence"]) < 1e-6:
                    if class_priority.get(b["label"],0) > class_priority.get(a["label"],0):
                        keep[-1] = b
                removed[j] = True
    uniq = []
    seen = set()
    for item in keep:
        key = tuple([round(x, 2) for x in item["bbox"]]) + (item["label"],)
        if key not in seen:
            uniq.append(item)
            seen.add(key)
    return uniq

def visualize_bboxes(image, boxes, title=None, save_path=None):
    img = np.array(image.convert("RGB"))
    label_colors = {}
    palette = [(0,255,0),(0,128,255),(255,0,0),(255,128,0),(128,0,255),(0,200,200)]
    for i,b in enumerate(sorted(list(set([x["label"] for x in boxes])))):
        label_colors[b] = palette[i % len(palette)]
    for b in boxes:
        x1,y1,x2,y2 = map(int, b["bbox"])
        lbl = b["label"]
        conf = b["confidence"]
        color = label_colors.get(lbl, (0,255,0))
        cv2.rectangle(img, (x1,y1),(x2,y2), color, 2)
        txt = f"{lbl} {conf:.2f}"
        cv2.putText(img, txt, (x1, max(0,y1-8)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.45, color, 2, lineType=cv2.LINE_AA)
    out = Image.fromarray(img)
    if save_path:
        out.save(save_path)
    return out

def process_image_with_yolo(model, image_path,
                            conf=0.5, model_iou=0.45,
                            pre_conf_thresh=0.5,
                            class_nms_iou=0.3,      # Lowered
                            merge_text_iou=0.1,     # Lowered
                            cross_iou_thresh=0.9999,
                            final_conf_thresh=0.5,
                            dedup_iou=0.2,          # Lowered
                            visualize=True,
                            out_before="before.png", out_after="after.png"):

    pil_img = Image.open(image_path).convert("RGB")
    raw_results = perform_prediction(pil_img, model, imgsz=1024, conf=conf, iou=model_iou, device="cpu")

    boxes = extract_bboxes(raw_results)
    counter_before = Counter([b["label"] for b in boxes])
    print("Before:", dict(counter_before), " total:", len(boxes))
    if visualize:
        visualize_bboxes(pil_img, boxes, save_path=out_before)

    # 1) Pre-filter
    boxes = [b for b in boxes if b["confidence"] >= pre_conf_thresh]
    print("Post pre-filter:", Counter([b["label"] for b in boxes]))

    # 2) Class-wise NMS
    boxes = nms_classwise(boxes, iou_thresh=class_nms_iou)
    print("Post NMS:", Counter([b["label"] for b in boxes]))

    # 3) Merge text (only if 'Text' boxes exist)
    if any(b["label"].lower() == "text" for b in boxes):
        boxes = merge_text_boxes(boxes, merge_iou=merge_text_iou)
    print("Post text merge:", Counter([b["label"] for b in boxes]))

    # 4) Cross-class resolution
    boxes = resolve_cross_class_conflicts(boxes, cross_iou_thresh=cross_iou_thresh)
    print("Post cross-class:", Counter([b["label"] for b in boxes]))

    # 5) Extra deduplication per class
    boxes = deduplicate_boxes(boxes, iou_thresh=dedup_iou)
    print("Post deduplication:", Counter([b["label"] for b in boxes]))

    # 6) Final filter
    boxes = [b for b in boxes if b["confidence"] >= final_conf_thresh]
    counter_after = Counter([b["label"] for b in boxes])
    print("After:", dict(counter_after), " total:", len(boxes))
    if visualize:
        visualize_bboxes(pil_img, boxes, save_path=out_after)

    return boxes

# %%
import json
from doclayout_yolo import YOLO

# Load model
model = YOLO("D:\OCR\Pipeline\yolov12l-doclaynet.pt")   # update with your model path

# Run pipeline
boxes = process_image_with_yolo(
    model=model,
    image_path="D:\OCR session\pic8.png",   # replace with your image
    conf=0.5,
    model_iou=0.45,
    visualize=True
)

# Convert result to JSON
boxes_json = json.dumps(boxes, indent=4)

# Print JSON
print(boxes_json)

# Optionally save to file
with open("output_boxes.json", "w") as f:
    f.write(boxes_json)
# Out:
# 0: 896x1024 1 List-item, 1 Section-header, 3 Tables, 1 Text, 9311.7ms
# Speed: 29.5ms preprocess, 9311.7ms inference, 2.0ms postprocess per image at shape (1, 3, 896, 1024)
# Before: {'Table': 3, 'Section-header': 1, 'List-item': 1, 'Text': 1}  total: 6
# Post pre-filter: Counter({'Table': 3, 'Section-header': 1, 'List-item': 1, 'Text': 1})
# Post NMS: Counter({'Table': 3, 'Text': 1, 'List-item': 1, 'Section-header': 1})
# Post text merge: Counter({'Table': 3, 'List-item': 1, 'Section-header': 1, 'Text': 1})
# Post cross-class: Counter({'Table': 3, 'Section-header': 1, 'List-item': 1, 'Text': 1})
# Post deduplication: Counter({'Table': 3, 'Text': 1, 'List-item': 1, 'Section-header': 1})
# After: {'Text': 1, 'List-item': 1, 'Table': 3, 'Section-header': 1}  total: 6
# [
#     {
#         "bbox": [
#             36.936012268066406,
#             9.474674224853516,
#             471.8370361328125,
#             27.387134552001953
#         ],
#         "label": "Text",
#         "confidence": 0.5258165597915649
#     },
#     {
#         "bbox": [
#             45.748172760009766,
#             51.36980438232422,
#             553.9479370117188,
#             114.7805404663086
#         ],
#         "label": "List-item",
#         "confidence": 0.6020355224609375
#     },
#     {
#         "bbox": [
#             88.7995376586914,
#             147.21142578125,
#             518.2014770507812,
#             269.10552978515625
#         ],
#         "label": "Table",
#         "confidence": 0.9431428909301758
#     },
#     {
#         "bbox": [
#             88.7920913696289,
#             473.3966064453125,
#             389.7344970703125,
#             643.7700805664062
#         ],
#         "label": "Table",
#         "confidence": 0.9387663006782532
#     },
#     {
#         "bbox": [
#             88.8464584350586,
#             310.0857238769531,
#             343.0762634277344,
#             432.3285217285156
#         ],
#         "label": "Table",
#         "confidence": 0.9094651341438293
#     },
#     {
#         "bbox": [
#             90.07296752929688,
#             127.6181640625,
#             164.007568359375,
#             148.13226318359375
#         ],
#         "label": "Section-header",
#         "confidence": 0.7473637461662292
#     }
# ]

# %%
# Final "after.png" result:
cleaned_img = Image.open("after.png")
cleaned_img.show()

# %%
print(model.info())
# Out:
# YOLOv12l summary: 488 layers, 26,397,585 parameters, 0 gradients, 89.5 GFLOPs
# (488, 26397585, 0, 89.4527744)

# %% [markdown]
# ---
# ## Saving paragraph crops
#
# ---

# %%
# === Fixed cropping + wrapper that uses your existing pipeline functions ===
import os
from PIL import Image

# Set this to the folder that contains your images (change if necessary)
IMAGES_DIR = r"D:\OCR session"     # <-- update if your images are in a different folder
OUTPUT_DIR_ROOT = r"D:\paragraph_crops"  # where crops will be saved

# If you already defined these functions in previous cells, this wrapper will use them:
# perform_prediction, extract_bboxes, nms_classwise, merge_text_boxes,
# resolve_cross_class_conflicts, deduplicate_boxes
# Also make sure `model` (YOLOv10 instance) is already created in your session.

def get_layout_bboxes_yolo(page_image, model,
                           pre_conf_thresh=0.5,
                           class_nms_iou=0.3,
                           merge_text_iou=0.1,
                           cross_iou_thresh=0.9999,
                           dedup_iou=0.2,
                           final_conf_thresh=0.5):
    """
    Returns cleaned layout boxes for a PIL page_image using existing pipeline functions.
    Assumes perform_prediction() and pipeline helper functions are defined in the session.
    """
    # 1) run model (perform_prediction accepts PIL image)
    raw_results = perform_prediction(page_image, model, imgsz=1024, conf=0.5, iou=0.45, device="cpu")

    # 2) extract boxes
    boxes = extract_bboxes(raw_results)

    # 3) pre-filter by confidence
    boxes = [b for b in boxes if b["confidence"] >= pre_conf_thresh]

    # 4) class-wise NMS
    boxes = nms_classwise(boxes, iou_thresh=class_nms_iou)

    # 5) merge text fragments (if any)
    if any(b["label"].lower() == "text" for b in boxes):
        boxes = merge_text_boxes(boxes, merge_iou=merge_text_iou)

    # 6) resolve perfect cross-class conflicts
    boxes = resolve_cross_class_conflicts(boxes, cross_iou_thresh=cross_iou_thresh)

    # 7) extra deduplication per class
    boxes = deduplicate_boxes(boxes, iou_thresh=dedup_iou)

    # 8) final confidence filter
    boxes = [b for b in boxes if b["confidence"] >= final_conf_thresh]

    # Return list of dicts: {"bbox":[x1,y1,x2,y2], "label":..., "confidence":...}
    return boxes


def crop_text_areas(page_image):
    """
    Takes a PIL page_image and returns list of PIL image crops for text areas.
    Uses get_layout_bboxes_yolo(...) to get cleaned layout boxes.
    """
    # call wrapper with the global `model` (must exist)
    bboxes = get_layout_bboxes_yolo(page_image, model)

    text_elements_list = []
    for item in bboxes:
        # correct unpacking order: x1, y1, x2, y2
        x1, y1, x2, y2 = map(int, item["bbox"])

        # skip figures/tables (you asked to crop text areas only)
        if item["label"].lower() not in ["figure", "table"]:
            # crop expects (left, upper, right, lower) => (x1,y1,x2,y2)
            crop = page_image.crop((x1, y1, x2, y2))
            # store crop and associated metadata (label, confidence)
            text_elements_list.append({
                "crop": crop,
                "label": item["label"],
                "confidence": item["confidence"],
                "bbox": [x1, y1, x2, y2]
            })
    return text_elements_list


def save_crops_for_page(page_image_filename):
    """
    Input: filename (just the file name, not full path) inside IMAGES_DIR.
    Saves crops to OUTPUT_DIR_ROOT/<filename_without_ext>/crop_i.jpg
    """
    print(f">>> Processing image: {page_image_filename}")
    image_path = os.path.join(IMAGES_DIR, page_image_filename)
    page_image = Image.open(image_path).convert("RGB")

    text_elements_crops = crop_text_areas(page_image)
    print(f"Total crops: {len(text_elements_crops)}")

    output_dir = os.path.join(OUTPUT_DIR_ROOT, os.path.splitext(page_image_filename)[0])
    os.makedirs(output_dir, exist_ok=True)

    for i, item in enumerate(text_elements_crops):
        print(f"Saving image crop {i}... label={item['label']} conf={item['confidence']:.3f}")
        crop = item["crop"]
        crop.save(os.path.join(output_dir, f"crop_{i}.jpg"))


# === Main loop: process all images in IMAGES_DIR ===
if __name__ == "__main__":
    # filter for common image extensions
    total_filenames = [f for f in os.listdir(IMAGES_DIR)
                       if f.lower().endswith((".png", ".jpg", ".jpeg", ".tiff", ".bmp"))]
    print(f"Total page images: {len(total_filenames)}")

    for filename in total_filenames:
        save_crops_for_page(filename)
# Out:
# Total page images: 90
# >>> Processing image: GTA 5 Receipt.png
# 0: 1024x1024 2 Section-headers, 1 Table, 6 Texts, 8697.9ms
# Speed: 47.6ms preprocess, 8697.9ms inference, 3.7ms postprocess per image at shape (1, 3, 1024, 1024)
# Total crops: 8
# Saving image crop 0... label=Section-header conf=0.721
# Saving image crop 1... label=Section-header conf=0.659
# Saving image crop 2... label=Text conf=0.868
# Saving image crop 3... label=Text conf=0.862
# Saving image crop 4... label=Text conf=0.791
# Saving image crop 5... label=Text conf=0.757
# Saving image crop 6... label=Text conf=0.726
# Saving image crop 7... label=Text conf=0.636
# >>> Processing image: im (12).png
#
# 0: 544x1024 5 List-items, 1 Section-header, 4016.4ms
# Speed: 17.8ms preprocess, 4016.4ms inference, 9.3ms postprocess per image at shape (1, 3, 544, 1024)
# Total crops: 6
# Saving image crop 0... label=List-item conf=0.962
# Saving image crop 1... label=List-item conf=0.956
# Saving image crop 2... label=List-item conf=0.954
# Saving image crop 3... label=List-item conf=0.938
# Saving image crop 4... label=List-item conf=0.876
# Saving image crop 5... label=Section-header conf=0.794
# >>> Processing image: im (13).png
#
# 0: 512x1024 (no detections), 2716.3ms
# Speed: 9.8ms preprocess, 2716.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 1024)
# Total crops: 0
# >>> Processing image: im (14).png
#
# 0: 512x1024 2 List-items, 1 Page-footer, 1 Picture, 2 Section-headers, 1 Text, 2691.3ms
# Speed: 5.5ms preprocess, 2691.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 1024)
# Total crops: 7
# Saving image crop 0... label=List-item conf=0.895
# Saving image crop 1... label=List-item conf=0.777
# Saving image crop 2... label=Picture conf=0.732
# Saving image crop 3... label=Page-footer conf=0.613
# Saving image crop 4... label=Section-header conf=0.847
# Saving image crop 5... label=Section-header conf=0.588
# Saving image crop 6... label=Text conf=0.811
# >>> Processing image: im (16).png
#
# 0: 512x1024 3 Pictures, 3 Texts, 2682.0ms
# Speed: 18.3ms preprocess, 2682.0ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 1024)
# Total crops: 6
# Saving image crop 0... label=Picture conf=0.957
# Saving image crop 1... label=Picture conf=0.896
# Saving image crop 2... label=Picture conf=0.624
# Saving image crop 3... label=Text conf=0.844
# Saving image crop 4... label=Text conf=0.703
# Saving image crop 5... label=Text conf=0.590
# >>> Processing image: im (17).png
#
# 0: 480x1024 1 Picture, 2454.8ms
# Speed: 4.0ms preprocess, 2454.8ms inference, 11.6ms postprocess per image at shape (1, 3, 480, 1024)
# Total crops: 1
# Saving image crop 0... label=Picture conf=0.798
# >>> Processing image: im (18).png
#
# 0: 608x1024 1 Picture, 3787.7ms
# Speed: 18.3ms preprocess, 3787.7ms inference, 8.2ms postprocess per image at shape (1, 3, 608, 1024)
# Total crops: 1
# Saving image crop 0... label=Picture conf=0.702
# >>> Processing image: im (19).png
#
# 0: 576x1024 1 Picture, 1 Section-header, 6 Texts, 4354.5ms
# Speed: 18.9ms preprocess, 4354.5ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 1024)
# Total crops: 8
# Saving image crop 0... label=Picture conf=0.834
# Saving image crop 1... label=Section-header conf=0.758
# Saving image crop 2... label=Text conf=0.800
# Saving image crop 3... label=Text conf=0.777
# Saving image crop 4... label=Text conf=0.762
# Saving image crop 5... label=Text conf=0.761
# Saving image crop 6... label=Text conf=0.709
# Saving image crop 7... label=Text conf=0.690
# >>> Processing image: im (2).png
#
# 0: 704x1024 2 Pictures, 1 Text, 4615.4ms
# Speed: 1.4ms preprocess, 4615.4ms inference, 2.2ms postprocess per image at shape (1, 3, 704, 1024)
# Total crops: 3
# Saving image crop 0... label=Picture conf=0.956
# Saving image crop 1... label=Picture conf=0.558
# Saving image crop 2... label=Text conf=0.801
# >>> Processing image: im (20).png
#
# 0: 576x1024 1 List-item, 1 Picture, 1 Text, 3550.0ms
# Speed: 2.8ms preprocess, 3550.0ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 1024)
# Total crops: 3
# Saving image crop 0... label=List-item conf=0.925
# Saving image crop 1... label=Picture conf=0.809
# Saving image crop 2... label=Text conf=0.872
# >>> Processing image: im (21).png
#
# 0: 544x1024 1 Picture, 1 Section-header, 2 Texts, 2504.4ms
# Speed: 0.0ms preprocess, 2504.4ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 1024)
# Total crops: 4
# Saving image crop 0... label=Picture conf=0.777
# Saving image crop 1... label=Section-header conf=0.732
# Saving image crop 2... label=Text conf=0.732
# Saving image crop 3... label=Text conf=0.617
# >>> Processing image: im (22).png
#
# 0: 832x1024 1 Picture, 4655.5ms
# Speed: 7.7ms preprocess, 4655.5ms inference, 15.8ms postprocess per image at shape (1, 3, 832, 1024)
# Total crops: 1
# Saving image crop 0... label=Picture conf=0.663
# >>> Processing image: im (25).png
#
# 0: 512x1024 1 Picture, 1 Text, 2389.3ms
# Speed: 17.1ms preprocess, 2389.3ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 1024)
# Total crops: 2
# Saving image crop 0... label=Picture conf=0.921
# Saving image crop 1... label=Text conf=0.899
# >>> Processing image: im (31).png
#
# 0: 480x1024 1 Title, 2174.6ms
# Speed: 0.0ms preprocess, 2174.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 1024)
# Total crops: 1
# Saving image crop 0... label=Title conf=0.626
# >>> Processing image: im (32).png
#
# 0: 256x1024 (no detections), 1111.0ms
# Speed: 10.7ms preprocess, 1111.0ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 1024)
# Total crops: 0
# >>> Processing image: im (33).png
#
# 0: 384x1024 (no detections), 1730.1ms
# Speed: 5.5ms preprocess, 1730.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 1024)
# Total crops: 0
# >>> Processing image: im (34).png
#
# 0: 320x1024 1 Picture, 1395.9ms
# Speed: 8.1ms preprocess, 1395.9ms inference, 0.0ms postprocess per image at shape (1, 3, 320, 1024)
# Total crops: 1
# Saving image crop 0... label=Picture conf=0.739
# >>> Processing image: im (35).png
#
# 0: 352x1024 1 Text, 1581.7ms
# Speed: 0.0ms preprocess, 1581.7ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 1024)
# Total crops: 1
# Saving image crop 0... label=Text conf=0.518
# >>> Processing image: im (36).png
#
# 0: 512x1024 2 List-items, 1 Section-header, 1 Text, 2365.4ms
# Speed: 0.0ms preprocess, 2365.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 1024)
# Total crops: 4
# Saving image crop 0... label=List-item conf=0.959
# Saving image crop 1... label=List-item conf=0.951
# Saving image crop 2... label=Section-header conf=0.665
# Saving image crop 3... label=Text conf=0.716
# >>> Processing image: im (37).png
#
# 0: 608x1024 8 List-items, 1 Picture, 1 Section-header, 3083.6ms
# Speed: 0.0ms preprocess, 3083.6ms inference, 0.0ms postprocess per image at shape (1, 3, 608, 1024)
# Total crops: 10
# Saving image crop 0... label=List-item conf=0.932
# Saving image crop 1... label=List-item conf=0.930
# Saving image crop 2... label=List-item conf=0.925
# Saving image crop 3... label=List-item conf=0.921
# Saving image crop 4... label=List-item conf=0.904
# Saving image crop 5... label=List-item conf=0.877
# Saving image crop 6... label=List-item conf=0.859
# Saving image crop 7... label=List-item conf=0.852
# Saving image crop 8... label=Picture conf=0.518
# Saving image crop 9... label=Section-header conf=0.767
# >>> Processing image: im (38).png
#
# 0: 576x1024 9 List-items, 2 Pictures, 1 Section-header, 2749.9ms
# Speed: 1.5ms preprocess, 2749.9ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 1024)
# Total crops: 12
# Saving image crop 0... label=Picture conf=0.749
# Saving image crop 1... label=Picture conf=0.551
# Saving image crop 2... label=List-item conf=0.733
# Saving image crop 3... label=List-item conf=0.710
# Saving image crop 4... label=List-item conf=0.668
# Saving image crop 5... label=List-item conf=0.660
# Saving image crop 6... label=List-item conf=0.654
# Saving image crop 7... label=List-item conf=0.623
# Saving image crop 8... label=List-item conf=0.525
# Saving image crop 9... label=List-item conf=0.525
# Saving image crop 10... label=List-item conf=0.516
# Saving image crop 11... label=Section-header conf=0.823
# >>> Processing image: im (39).png
#
# 0: 544x1024 6 List-items, 1 Picture, 1 Section-header, 2700.2ms
# Speed: 8.1ms preprocess, 2700.2ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 1024)
# Total crops: 8
# Saving image crop 0... label=List-item conf=0.965
# Saving image crop 1... label=List-item conf=0.961
# Saving image crop 2... label=List-item conf=0.955
# Saving image crop 3... label=List-item conf=0.934
# Saving image crop 4... label=List-item conf=0.859
# Saving image crop 5... label=List-item conf=0.537
# Saving image crop 6... label=Picture conf=0.900
# Saving image crop 7... label=Section-header conf=0.854
# >>> Processing image: im (4).png
#
# 0: 608x1024 1 Picture, 2 Texts, 4300.8ms
# Speed: 0.0ms preprocess, 4300.8ms inference, 8.3ms postprocess per image at shape (1, 3, 608, 1024)
# Total crops: 3
# Saving image crop 0... label=Picture conf=0.700
# Saving image crop 1... label=Text conf=0.538
# Saving image crop 2... label=Text conf=0.520
# >>> Processing image: im (40).png
#
# 0: 512x1024 1 Picture, 1 Title, 3044.7ms
# Speed: 14.3ms preprocess, 3044.7ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 1024)
# Total crops: 2
# Saving image crop 0... label=Picture conf=0.823
# Saving image crop 1... label=Title conf=0.528
# >>> Processing image: im (41).png
#
# 0: 448x1024 4 List-items, 1 Picture, 1 Section-header, 3186.2ms
# Speed: 15.2ms preprocess, 3186.2ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 1024)
# Total crops: 6
# Saving image crop 0... label=List-item conf=0.949
# Saving image crop 1... label=List-item conf=0.928
# Saving image crop 2... label=List-item conf=0.913
# Saving image crop 3... label=List-item conf=0.908
# Saving image crop 4... label=Picture conf=0.858
# Saving image crop 5... label=Section-header conf=0.803
# >>> Processing image: im (42).png
#
# 0: 544x1024 4 List-items, 2 Pictures, 1 Section-header, 3158.4ms
# Speed: 1.5ms preprocess, 3158.4ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 1024)
# Total crops: 7
# Saving image crop 0... label=List-item conf=0.955
# Saving image crop 1... label=List-item conf=0.954
# Saving image crop 2... label=List-item conf=0.954
# Saving image crop 3... label=List-item conf=0.952
# Saving image crop 4... label=Picture conf=0.830
# Saving image crop 5... label=Picture conf=0.686
# Saving image crop 6... label=Section-header conf=0.719
# >>> Processing image: im (43).png
#
# 0: 640x1024 (no detections), 4724.1ms
# Speed: 3.6ms preprocess, 4724.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 1024)
# Total crops: 0
# >>> Processing image: im (44).png
#
# 0: 544x1024 2 Pictures, 1 Section-header, 2556.6ms
# Speed: 15.8ms preprocess, 2556.6ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 1024)
# Total crops: 3
# Saving image crop 0... label=Picture conf=0.821
# Saving image crop 1... label=Picture conf=0.562
# Saving image crop 2... label=Section-header conf=0.548
# >>> Processing image: im (45).png
#
# 0: 544x1024 2 List-items, 1 Picture, 1 Section-header, 2 Texts, 2635.4ms
# Speed: 0.0ms preprocess, 2635.4ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 1024)
# Total crops: 6
# Saving image crop 0... label=List-item conf=0.933
# Saving image crop 1... label=List-item conf=0.583
# Saving image crop 2... label=Section-header conf=0.570
# Saving image crop 3... label=Picture conf=0.907
# Saving image crop 4... label=Text conf=0.940
# Saving image crop 5... label=Text conf=0.655
# >>> Processing image: im (46).png
#
# 0: 544x1024 2 List-items, 2 Pictures, 1 Section-header, 2449.9ms
# Speed: 0.0ms preprocess, 2449.9ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 1024)
# Total crops: 5
# Saving image crop 0... label=List-item conf=0.968
# Saving image crop 1... label=List-item conf=0.964
# Saving image crop 2... label=Picture conf=0.926
# Saving image crop 3... label=Picture conf=0.790
# Saving image crop 4... label=Section-header conf=0.675
# >>> Processing image: im (47).png
#
# 0: 640x1024 2 List-items, 1 Picture, 1 Section-header, 2997.8ms
# Speed: 18.6ms preprocess, 2997.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 1024)
# Total crops: 4
# Saving image crop 0... label=List-item conf=0.837
# Saving image crop 1... label=List-item conf=0.588
# Saving image crop 2... label=Picture conf=0.800
# Saving image crop 3... label=Section-header conf=0.721
# >>> Processing image: im (48).png
#
# 0: 448x1024 1 Picture, 1 Text, 1965.2ms
# Speed: 0.0ms preprocess, 1965.2ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 1024)
# Total crops: 2
# Saving image crop 0... label=Picture conf=0.716
# Saving image crop 1... label=Text conf=0.692
# >>> Processing image: im (49).png
#
# 0: 576x1024 2 List-items, 1 Picture, 2 Section-headers, 1 Text, 2648.4ms
# Speed: 8.0ms preprocess, 2648.4ms inference, 16.4ms postprocess per image at shape (1, 3, 576, 1024)
# Total crops: 6
# Saving image crop 0... label=List-item conf=0.961
# Saving image crop 1... label=List-item conf=0.957
# Saving image crop 2... label=Text conf=0.880
# Saving image crop 3... label=Section-header conf=0.884
# Saving image crop 4... label=Section-header conf=0.848
# Saving image crop 5... label=Picture conf=0.515
# >>> Processing image: im (5).png
#
# 0: 448x1024 1 Picture, 2443.7ms
# Speed: 0.0ms preprocess, 2443.7ms inference, 0.0ms postprocess per image at shape (1, 3, 448, 1024)
# Total crops: 1
# Saving image crop 0... label=Picture conf=0.814
# >>> Processing image: im (50).png
#
# 0: 544x1024 6 List-items, 1 Picture, 1 Section-header, 2825.5ms
# Speed: 12.3ms preprocess, 2825.5ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 1024)
# Total crops: 8
# Saving image crop 0... label=Picture conf=0.955
# Saving image crop 1... label=List-item conf=0.954
# Saving image crop 2... label=List-item conf=0.954
# Saving image crop 3... label=List-item conf=0.951
# Saving image crop 4... label=List-item conf=0.951
# Saving image crop 5... label=List-item conf=0.946
# Saving image crop 6... label=List-item conf=0.946
# Saving image crop 7... label=Section-header conf=0.610
# >>> Processing image: im (51).png
#
# 0: 576x1024 2 Pictures, 2 Section-headers, 8 Texts, 3239.4ms
# Speed: 9.9ms preprocess, 3239.4ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 1024)
# Total crops: 12
# Saving image crop 0... label=Picture conf=0.883
# Saving image crop 1... label=Picture conf=0.806
# Saving image crop 2... label=Section-header conf=0.747
# Saving image crop 3... label=Section-header conf=0.645
# Saving image crop 4... label=Text conf=0.940
# Saving image crop 5... label=Text conf=0.895
# Saving image crop 6... label=Text conf=0.831
# Saving image crop 7... label=Text conf=0.801
# Saving image crop 8... label=Text conf=0.736
# Saving image crop 9... label=Text conf=0.598
# Saving image crop 10... label=Text conf=0.563
# Saving image crop 11... label=Text conf=0.538
# >>> Processing image: im (53).png
#
# 0: 480x1024 1 Table, 3246.1ms
# Speed: 7.8ms preprocess, 3246.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 1024)
# Total crops: 0
# >>> Processing image: im (54).png
#
# 0: 480x1024 1 Table, 2499.4ms
# Speed: 15.7ms preprocess, 2499.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 1024)
# Total crops: 0
# >>> Processing image: im (6).png
#
# 0: 512x1024 1 Picture, 1 Section-header, 2401.4ms
# Speed: 8.6ms preprocess, 2401.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 1024)
# Total crops: 2
# Saving image crop 0... label=Picture conf=0.676
# Saving image crop 1... label=Section-header conf=0.539
# >>> Processing image: im (7).png
#
# 0: 544x1024 1 List-item, 1 Picture, 1 Section-header, 1 Text, 2494.2ms
# Speed: 9.4ms preprocess, 2494.2ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 1024)
# Total crops: 4
# Saving image crop 0... label=List-item conf=0.932
# Saving image crop 1... label=Section-header conf=0.658
# Saving image crop 2... label=Picture conf=0.917
# Saving image crop 3... label=Text conf=0.673
# >>> Processing image: im (8).png
#
# 0: 928x1024 2 Texts, 4885.4ms
# Speed: 8.1ms preprocess, 4885.4ms inference, 0.0ms postprocess per image at shape (1, 3, 928, 1024)
# Total crops: 2
# Saving image crop 0... label=Text conf=0.549
# Saving image crop 1... label=Text conf=0.537
# >>> Processing image: im (9).png
#
# 0: 544x1024 4 List-items, 1 Picture, 1 Section-header, 3 Texts, 2463.7ms
# Speed: 11.8ms preprocess, 2463.7ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 1024)
# Total crops: 9
# Saving image crop 0... label=List-item conf=0.905
# Saving image crop 1... label=List-item conf=0.884
# Saving image crop 2... label=List-item conf=0.880
# Saving image crop 3... label=List-item conf=0.836
# Saving image crop 4... label=Section-header conf=0.832
# Saving image crop 5... label=Picture conf=0.648
# Saving image crop 6... label=Text conf=0.912
# Saving image crop 7... label=Text conf=0.820
# Saving image crop 8... label=Text conf=0.762
# >>> Processing image: image-62.png
#
# 0: 800x1024 1 Table, 4084.3ms
# Speed: 11.6ms preprocess, 4084.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 1024)
# Total crops: 0
# >>> Processing image: Interior-04.jpg
#
# 0: 1024x672 1 Page-footer, 1 Page-header, 1 Section-header, 6 Texts, 3283.2ms
# Speed: 8.1ms preprocess, 3283.2ms inference, 0.0ms postprocess per image at shape (1, 3, 1024, 672)
# Total crops: 9
# Saving image crop 0... label=Section-header conf=0.735
# Saving image crop 1... label=Page-header conf=0.511
# Saving image crop 2... label=Text conf=0.975
# Saving image crop 3... label=Text conf=0.970
# Saving image crop 4... label=Text conf=0.959
# Saving image crop 5... label=Text conf=0.938
# Saving image crop 6... label=Text conf=0.891
# Saving image crop 7... label=Text conf=0.821
# Saving image crop 8... label=Page-footer conf=0.511
# >>> Processing image: p2.png
#
# 0: 1024x1024 1 Section-header, 6744.2ms
# Speed: 15.1ms preprocess, 6744.2ms inference, 0.0ms postprocess per image at shape (1, 3, 1024, 1024)
# Total crops: 1
# Saving image crop 0... label=Section-header conf=0.605
# >>> Processing image: pic10.jpg
#
# 0: 672x1024 1 Caption, 2 Page-footers, 2 Pictures, 1 Section-header, 20 Texts, 3501.8ms
# Speed: 11.2ms preprocess, 3501.8ms inference, 0.0ms postprocess per image at shape (1, 3, 672, 1024)
# Total crops: 26
# Saving image crop 0... label=Picture conf=0.910
# Saving image crop 1... label=Picture conf=0.606
# Saving image crop 2... label=Page-footer conf=0.711
# Saving image crop 3... label=Page-footer conf=0.690
# Saving image crop 4... label=Section-header conf=0.853
# Saving image crop 5... label=Caption conf=0.903
# Saving image crop 6... label=Text conf=0.971
# Saving image crop 7... label=Text conf=0.971
# Saving image crop 8... label=Text conf=0.970
# Saving image crop 9... label=Text conf=0.970
# Saving image crop 10... label=Text conf=0.968
# Saving image crop 11... label=Text conf=0.968
# Saving image crop 12... label=Text conf=0.967
# Saving image crop 13... label=Text conf=0.966
# Saving image crop 14... label=Text conf=0.964
# Saving image crop 15... label=Text conf=0.963
# Saving image crop 16... label=Text conf=0.962
# Saving image crop 17... label=Text conf=0.960
# Saving image crop 18... label=Text conf=0.953
# Saving image crop 19... label=Text conf=0.952
# Saving image crop 20... label=Text conf=0.949
# Saving image crop 21... label=Text conf=0.923
# Saving image crop 22... label=Text conf=0.922
# Saving image crop 23... label=Text conf=0.880
# Saving image crop 24... label=Text conf=0.873
# Saving image crop 25... label=Text conf=0.726
# >>> Processing image: pic11.png
#
# 0: 1024x800 2 Pictures, 4 Section-headers, 9 Texts, 4068.0ms
# Speed: 18.5ms preprocess, 4068.0ms inference, 0.0ms postprocess per image at shape (1, 3, 1024, 800)
# Total crops: 15
# Saving image crop 0... label=Picture conf=0.956
# Saving image crop 1... label=Picture conf=0.923
# Saving image crop 2... label=Section-header conf=0.915
# Saving image crop 3... label=Section-header conf=0.814
# Saving image crop 4... label=Section-header conf=0.731
# Saving image crop 5... label=Section-header conf=0.537
# Saving image crop 6... label=Text conf=0.977
# Saving image crop 7... label=Text conf=0.976
# Saving image crop 8... label=Text conf=0.973
# Saving image crop 9... label=Text conf=0.963
# Saving image crop 10... label=Text conf=0.962
# Saving image crop 11... label=Text conf=0.936
# Saving image crop 12... label=Text conf=0.891
# Saving image crop 13... label=Text conf=0.879
# Saving image crop 14... label=Text conf=0.659
# >>> Processing image: pic12.png
#
# 0: 1024x768 2 Page-footers, 1 Picture, 10 Texts, 3809.8ms
# Speed: 16.3ms preprocess, 3809.8ms inference, 0.0ms postprocess per image at shape (1, 3, 1024, 768)
# Total crops: 13
# Saving image crop 0... label=Picture conf=0.878
# Saving image crop 1... label=Page-footer conf=0.643
# Saving image crop 2... label=Page-footer conf=0.630
# Saving image crop 3... label=Text conf=0.978
# Saving image crop 4... label=Text conf=0.976
# Saving image crop 5... label=Text conf=0.974
# Saving image crop 6... label=Text conf=0.968
# Saving image crop 7... label=Text conf=0.967
# Saving image crop 8... label=Text conf=0.966
# Saving image crop 9... label=Text conf=0.949
# Saving image crop 10... label=Text conf=0.930
# Saving image crop 11... label=Text conf=0.589
# Saving image crop 12... label=Text conf=0.527
# >>> Processing image: pic13.jpg
#
# 0: 1024x800 2 Pictures, 1 Section-header, 2 Texts, 3826.5ms
# Speed: 10.0ms preprocess, 3826.5ms inference, 2.0ms postprocess per image at shape (1, 3, 1024, 800)
# Total crops: 5
# Saving image crop 0... label=Picture conf=0.716
# Saving image crop 1... label=Picture conf=0.580
# Saving image crop 2... label=Text conf=0.767
# Saving image crop 3... label=Text conf=0.702
# Saving image crop 4... label=Section-header conf=0.770
# >>> Processing image: pic14.png
#
# 0: 1024x992 1 Picture, 5 Texts, 5069.3ms
# Speed: 14.8ms preprocess, 5069.3ms inference, 0.0ms postprocess per image at shape (1, 3, 1024, 992)
# Total crops: 6
# Saving image crop 0... label=Picture conf=0.619
# Saving image crop 1... label=Text conf=0.808
# Saving image crop 2... label=Text conf=0.698
# Saving image crop 3... label=Text conf=0.674
# Saving image crop 4... label=Text conf=0.551
# Saving image crop 5... label=Text conf=0.511
# >>> Processing image: pic15.jpg
#
# 0: 640x1024 1 Caption, 2 Page-footers, 3 Pictures, 3 Section-headers, 21 Texts, 3036.8ms
# Speed: 16.1ms preprocess, 3036.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 1024)
# Total crops: 30
# Saving image crop 0... label=Picture conf=0.932
# Saving image crop 1... label=Picture conf=0.925
# Saving image crop 2... label=Picture conf=0.878
# Saving image crop 3... label=Page-footer conf=0.579
# Saving image crop 4... label=Page-footer conf=0.571
# Saving image crop 5... label=Section-header conf=0.861
# Saving image crop 6... label=Section-header conf=0.683
# Saving image crop 7... label=Section-header conf=0.519
# Saving image crop 8... label=Caption conf=0.583
# Saving image crop 9... label=Text conf=0.971
# Saving image crop 10... label=Text conf=0.971
# Saving image crop 11... label=Text conf=0.964
# Saving image crop 12... label=Text conf=0.964
# Saving image crop 13... label=Text conf=0.962
# Saving image crop 14... label=Text conf=0.959
# Saving image crop 15... label=Text conf=0.957
# Saving image crop 16... label=Text conf=0.956
# Saving image crop 17... label=Text conf=0.954
# Saving image crop 18... label=Text conf=0.953
# Saving image crop 19... label=Text conf=0.947
# Saving image crop 20... label=Text conf=0.923
# Saving image crop 21... label=Text conf=0.921
# Saving image crop 22... label=Text conf=0.905
# Saving image crop 23... label=Text conf=0.872
# Saving image crop 24... label=Text conf=0.860
# Saving image crop 25... label=Text conf=0.852
# Saving image crop 26... label=Text conf=0.670
# Saving image crop 27... label=Text conf=0.621
# Saving image crop 28... label=Text conf=0.620
# Saving image crop 29... label=Text conf=0.549
# >>> Processing image: pic16.jpg
#
# 0: 736x1024 (no detections), 3537.5ms
# Speed: 0.0ms preprocess, 3537.5ms inference, 0.0ms postprocess per image at shape (1, 3, 736, 1024)
# Total crops: 0
# >>> Processing image: pic17.png
#
# 0: 352x1024 2 Tables, 1423.5ms
# Speed: 11.8ms preprocess, 1423.5ms inference, 0.0ms postprocess per image at shape (1, 3, 352, 1024)
# Total crops: 0
# >>> Processing image: pic18.jpg
#
# 0: 1024x864 1 Picture, 2 Texts, 4805.7ms
# Speed: 13.9ms preprocess, 4805.7ms inference, 7.2ms postprocess per image at shape (1, 3, 1024, 864)
# Total crops: 3
# Saving image crop 0... label=Picture conf=0.800
# Saving image crop 1... label=Text conf=0.880
# Saving image crop 2... label=Text conf=0.816
# >>> Processing image: pic3.jpg
#
# 0: 1024x672 2 Pictures, 1 Section-header, 6 Texts, 3717.4ms
# Speed: 17.9ms preprocess, 3717.4ms inference, 0.0ms postprocess per image at shape (1, 3, 1024, 672)
# Total crops: 9
# Saving image crop 0... label=Picture conf=0.901
# Saving image crop 1... label=Picture conf=0.660
# Saving image crop 2... label=Section-header conf=0.852
# Saving image crop 3... label=Text conf=0.928
# Saving image crop 4... label=Text conf=0.873
# Saving image crop 5... label=Text conf=0.746
# Saving image crop 6... label=Text conf=0.702
# Saving image crop 7... label=Text conf=0.663
# Saving image crop 8... label=Text conf=0.650
# >>> Processing image: pic4.png
#
# 0: 1024x704 1 Picture, 1 Section-header, 5 Texts, 4618.9ms
# Speed: 13.2ms preprocess, 4618.9ms inference, 0.0ms postprocess per image at shape (1, 3, 1024, 704)
# Total crops: 7
# Saving image crop 0... label=Picture conf=0.965
# Saving image crop 1... label=Section-header conf=0.811
# Saving image crop 2... label=Text conf=0.954
# Saving image crop 3... label=Text conf=0.950
# Saving image crop 4... label=Text conf=0.920
# Saving image crop 5... label=Text conf=0.886
# Saving image crop 6... label=Text conf=0.807
# >>> Processing image: pic5.jpg
#
# 0: 1024x672 2 Pictures, 1 Section-header, 5 Texts, 3582.9ms
# Speed: 16.4ms preprocess, 3582.9ms inference, 0.0ms postprocess per image at shape (1, 3, 1024, 672)
# Total crops: 8
# Saving image crop 0... label=Picture conf=0.897
# Saving image crop 1... label=Picture conf=0.894
# Saving image crop 2... label=Section-header conf=0.805
# Saving image crop 3... label=Text conf=0.949
# Saving image crop 4... label=Text conf=0.920
# Saving image crop 5... label=Text conf=0.889
# Saving image crop 6... label=Text conf=0.793
# Saving image crop 7... label=Text conf=0.738
# >>> Processing image: pic6.jpeg
#
# 0: 416x1024 1 List-item, 1 Table, 1 Text, 1943.6ms
# Speed: 6.8ms preprocess, 1943.6ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 1024)
# Total crops: 2
# Saving image crop 0... label=List-item conf=0.790
# Saving image crop 1... label=Text conf=0.663
# >>> Processing image: pic7.png
#
# 0: 1024x736 1 Picture, 4 Texts, 3984.4ms
# Speed: 9.7ms preprocess, 3984.4ms inference, 0.0ms postprocess per image at shape (1, 3, 1024, 736)
# Total crops: 5
# Saving image crop 0... label=Picture conf=0.553
# Saving image crop 1... label=Text conf=0.917
# Saving image crop 2... label=Text conf=0.861
# Saving image crop 3... label=Text conf=0.647
# Saving image crop 4... label=Text conf=0.623
# >>> Processing image: pic8.png
#
# 0: 896x1024 1 List-item, 1 Section-header, 3 Tables, 1 Text, 4946.4ms
# Speed: 4.5ms preprocess, 4946.4ms inference, 0.0ms postprocess per image at shape (1, 3, 896, 1024)
# Total crops: 3
# Saving image crop 0... label=List-item conf=0.602
# Saving image crop 1... label=Text conf=0.526
# Saving image crop 2... label=Section-header conf=0.747
# >>> Processing image: pic9.jpg
#
# 0: 1024x768 2 Page-footers, 2 Pictures, 6 Texts, 4217.7ms
# Speed: 12.0ms preprocess, 4217.7ms inference, 0.0ms postprocess per image at shape (1, 3, 1024, 768)
# Total crops: 10
# Saving image crop 0... label=Picture conf=0.907
# Saving image crop 1... label=Picture conf=0.616
# Saving image crop 2... label=Page-footer conf=0.749
# Saving image crop 3... label=Page-footer conf=0.734
# Saving image crop 4... label=Text conf=0.952
# Saving image crop 5... label=Text conf=0.930
# Saving image crop 6... label=Text conf=0.925
# Saving image crop 7... label=Text conf=0.914
# Saving image crop 8... label=Text conf=0.888
# Saving image crop 9... label=Text conf=0.843
# >>> Processing image: Screenshot 2025-09-12 121803.png
#
# 0: 544x1024 6 List-items, 1 Picture, 1 Section-header, 2855.8ms
# Speed: 0.0ms preprocess, 2855.8ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 1024)
# Total crops: 8
# Saving image crop 0... label=List-item conf=0.965
# Saving image crop 1... label=List-item conf=0.961
# Saving image crop 2... label=List-item conf=0.955
# Saving image crop 3... label=List-item conf=0.934
# Saving image crop 4... label=List-item conf=0.859
# Saving image crop 5... label=List-item conf=0.537
# Saving image crop 6... label=Picture conf=0.900
# Saving image crop 7... label=Section-header conf=0.854
# >>> Processing image: Screenshot 2025-09-13 103129.png
#
# 0: 544x1024 1 Page-footer, 2 Pictures, 2722.7ms
# Speed: 8.1ms preprocess, 2722.7ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 1024)
# Total crops: 3
# Saving image crop 0... label=Picture conf=0.812
# Saving image crop 1... label=Picture conf=0.588
# Saving image crop 2... label=Page-footer conf=0.546
# >>> Processing image: Screenshot 2025-09-13 103202.png
#
# 0: 480x1024 3 List-items, 1 Page-footer, 1 Picture, 1 Text, 2772.8ms
# Speed: 7.8ms preprocess, 2772.8ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 1024)
# Total crops: 6
# Saving image crop 0... label=Picture conf=0.799
# Saving image crop 1... label=List-item conf=0.759
# Saving image crop 2... label=List-item conf=0.737
# Saving image crop 3... label=List-item conf=0.725
# Saving image crop 4... label=Page-footer conf=0.533
# Saving image crop 5... label=Text conf=0.774
# >>> Processing image: Screenshot 2025-09-13 103240.png
#
# 0: 544x1024 32 List-items, 1 Picture, 1 Section-header, 2924.6ms
# Speed: 8.5ms preprocess, 2924.6ms inference, 8.0ms postprocess per image at shape (1, 3, 544, 1024)
# Total crops: 34
# Saving image crop 0... label=Picture conf=0.834
# Saving image crop 1... label=List-item conf=0.805
# Saving image crop 2... label=List-item conf=0.799
# Saving image crop 3... label=List-item conf=0.780
# Saving image crop 4... label=List-item conf=0.780
# Saving image crop 5... label=List-item conf=0.772
# Saving image crop 6... label=List-item conf=0.767
# Saving image crop 7... label=List-item conf=0.757
# Saving image crop 8... label=List-item conf=0.746
# Saving image crop 9... label=List-item conf=0.741
# Saving image crop 10... label=List-item conf=0.738
# Saving image crop 11... label=List-item conf=0.736
# Saving image crop 12... label=List-item conf=0.728
# Saving image crop 13... label=List-item conf=0.727
# Saving image crop 14... label=List-item conf=0.726
# Saving image crop 15... label=List-item conf=0.718
# Saving image crop 16... label=List-item conf=0.715
# Saving image crop 17... label=List-item conf=0.712
# Saving image crop 18... label=List-item conf=0.703
# Saving image crop 19... label=List-item conf=0.702
# Saving image crop 20... label=List-item conf=0.699
# Saving image crop 21... label=List-item conf=0.698
# Saving image crop 22... label=List-item conf=0.694
# Saving image crop 23... label=List-item conf=0.684
# Saving image crop 24... label=List-item conf=0.676
# Saving image crop 25... label=List-item conf=0.674
# Saving image crop 26... label=List-item conf=0.673
# Saving image crop 27... label=List-item conf=0.673
# Saving image crop 28... label=List-item conf=0.668
# Saving image crop 29... label=List-item conf=0.667
# Saving image crop 30... label=List-item conf=0.653
# Saving image crop 31... label=List-item conf=0.643
# Saving image crop 32... label=List-item conf=0.606
# Saving image crop 33... label=Section-header conf=0.612
# >>> Processing image: Screenshot 2025-09-13 103349.png
#
# 0: 544x1024 2 Pictures, 1 Table, 1 Text, 2674.4ms
# Speed: 8.5ms preprocess, 2674.4ms inference, 0.0ms postprocess per image at shape (1, 3, 544, 1024)
# Total crops: 3
# Saving image crop 0... label=Picture conf=0.876
# Saving image crop 1... label=Picture conf=0.645
# Saving image crop 2... label=Text conf=0.555
# >>> Processing image: Screenshot 2025-09-16 140433.png
#
# 0: 704x1024 11 Texts, 4036.6ms
# Speed: 20.6ms preprocess, 4036.6ms inference, 0.0ms postprocess per image at shape (1, 3, 704, 1024)
# Total crops: 10
# Saving image crop 0... label=Text conf=0.725
# Saving image crop 1... label=Text conf=0.652
# Saving image crop 2... label=Text conf=0.621
# Saving image crop 3... label=Text conf=0.601
# Saving image crop 4... label=Text conf=0.569
# Saving image crop 5... label=Text conf=0.564
# Saving image crop 6... label=Text conf=0.563
# Saving image crop 7... label=Text conf=0.532
# Saving image crop 8... label=Text conf=0.525
# Saving image crop 9... label=Text conf=0.512
# >>> Processing image: Screenshot 2025-09-16 140852.png
#
# 0: 704x1024 11 Texts, 4274.7ms
# Speed: 7.8ms preprocess, 4274.7ms inference, 0.0ms postprocess per image at shape (1, 3, 704, 1024)
# Total crops: 11
# Saving image crop 0... label=Text conf=0.663
# Saving image crop 1... label=Text conf=0.629
# Saving image crop 2... label=Text conf=0.623
# Saving image crop 3... label=Text conf=0.621
# Saving image crop 4... label=Text conf=0.614
# Saving image crop 5... label=Text conf=0.605
# Saving image crop 6... label=Text conf=0.602
# Saving image crop 7... label=Text conf=0.593
# Saving image crop 8... label=Text conf=0.570
# Saving image crop 9... label=Text conf=0.565
# Saving image crop 10... label=Text conf=0.503
# >>> Processing image: Screenshot 2025-09-16 141808.png
#
# 0: 512x1024 1 Picture, 1 Text, 3814.4ms
# Speed: 13.8ms preprocess, 3814.4ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 1024)
# Total crops: 2
# Saving image crop 0... label=Picture conf=0.916
# Saving image crop 1... label=Text conf=0.898
# >>> Processing image: Screenshot 2025-09-16 141938.png
#
# 0: 672x1024 9 Texts, 5067.9ms
# Speed: 25.5ms preprocess, 5067.9ms inference, 0.0ms postprocess per image at shape (1, 3, 672, 1024)
# Total crops: 9
# Saving image crop 0... label=Text conf=0.793
# Saving image crop 1... label=Text conf=0.649
# Saving image crop 2... label=Text conf=0.613
# Saving image crop 3... label=Text conf=0.602
# Saving image crop 4... label=Text conf=0.600
# Saving image crop 5... label=Text conf=0.594
# Saving image crop 6... label=Text conf=0.575
# Saving image crop 7... label=Text conf=0.538
# Saving image crop 8... label=Text conf=0.507
# >>> Processing image: Screenshot 2025-09-16 152809.png
#
# 0: 736x1024 5 Texts, 4451.0ms
# Speed: 26.0ms preprocess, 4451.0ms inference, 2.0ms postprocess per image at shape (1, 3, 736, 1024)
# Total crops: 5
# Saving image crop 0... label=Text conf=0.827
# Saving image crop 1... label=Text conf=0.583
# Saving image crop 2... label=Text conf=0.558
# Saving image crop 3... label=Text conf=0.552
# Saving image crop 4... label=Text conf=0.545
# >>> Processing image: Screenshot 2025-09-16 154754.png
#
# 0: 640x1024 4 Texts, 3918.1ms
# Speed: 14.0ms preprocess, 3918.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 1024)
# Total crops: 4
# Saving image crop 0... label=Text conf=0.924
# Saving image crop 1... label=Text conf=0.584
# Saving image crop 2... label=Text conf=0.546
# Saving image crop 3... label=Text conf=0.523
# >>> Processing image: Screenshot 2025-09-16 161605.png
#
# 0: 640x1024 13 Texts, 4047.9ms
# Speed: 5.0ms preprocess, 4047.9ms inference, 15.7ms postprocess per image at shape (1, 3, 640, 1024)
# Total crops: 13
# Saving image crop 0... label=Text conf=0.761
# Saving image crop 1... label=Text conf=0.753
# Saving image crop 2... label=Text conf=0.709
# Saving image crop 3... label=Text conf=0.691
# Saving image crop 4... label=Text conf=0.686
# Saving image crop 5... label=Text conf=0.666
# Saving image crop 6... label=Text conf=0.662
# Saving image crop 7... label=Text conf=0.623
# Saving image crop 8... label=Text conf=0.620
# Saving image crop 9... label=Text conf=0.613
# Saving image crop 10... label=Text conf=0.564
# Saving image crop 11... label=Text conf=0.558
# Saving image crop 12... label=Text conf=0.504
# >>> Processing image: Screenshot 2025-09-16 162130.png
#
# 0: 672x1024 13 Texts, 3509.7ms
# Speed: 8.6ms preprocess, 3509.7ms inference, 0.0ms postprocess per image at shape (1, 3, 672, 1024)
# Total crops: 13
# Saving image crop 0... label=Text conf=0.698
# Saving image crop 1... label=Text conf=0.682
# Saving image crop 2... label=Text conf=0.679
# Saving image crop 3... label=Text conf=0.662
# Saving image crop 4... label=Text conf=0.660
# Saving image crop 5... label=Text conf=0.658
# Saving image crop 6... label=Text conf=0.634
# Saving image crop 7... label=Text conf=0.631
# Saving image crop 8... label=Text conf=0.615
# Saving image crop 9... label=Text conf=0.605
# Saving image crop 10... label=Text conf=0.585
# Saving image crop 11... label=Text conf=0.575
# Saving image crop 12... label=Text conf=0.575
# >>> Processing image: Screenshot 2025-09-16 162603.png
#
# 0: 672x1024 7 Texts, 4348.7ms
# Speed: 16.4ms preprocess, 4348.7ms inference, 0.0ms postprocess per image at shape (1, 3, 672, 1024)
# Total crops: 7
# Saving image crop 0... label=Text conf=0.630
# Saving image crop 1... label=Text conf=0.608
# Saving image crop 2... label=Text conf=0.577
# Saving image crop 3... label=Text conf=0.551
# Saving image crop 4... label=Text conf=0.547
# Saving image crop 5... label=Text conf=0.534
# Saving image crop 6... label=Text conf=0.523
# >>> Processing image: Screenshot 2025-09-16 163132.png
#
# 0: 672x1024 1 Page-footer, 10 Texts, 3906.3ms
# Speed: 20.4ms preprocess, 3906.3ms inference, 18.1ms postprocess per image at shape (1, 3, 672, 1024)
# Total crops: 11
# Saving image crop 0... label=Page-footer conf=0.519
# Saving image crop 1... label=Text conf=0.632
# Saving image crop 2... label=Text conf=0.632
# Saving image crop 3... label=Text conf=0.580
# Saving image crop 4... label=Text conf=0.569
# Saving image crop 5... label=Text conf=0.553
# Saving image crop 6... label=Text conf=0.531
# Saving image crop 7... label=Text conf=0.526
# Saving image crop 8... label=Text conf=0.515
# Saving image crop 9... label=Text conf=0.510
# Saving image crop 10... label=Text conf=0.508
# >>> Processing image: Screenshot 2025-09-16 231149.png
#
# 0: 512x1024 2 Pictures, 1 Table, 3 Texts, 2852.5ms
# Speed: 9.4ms preprocess, 2852.5ms inference, 0.0ms postprocess per image at shape (1, 3, 512, 1024)
# Total crops: 5
# Saving image crop 0... label=Picture conf=0.611
# Saving image crop 1... label=Picture conf=0.535
# Saving image crop 2... label=Text conf=0.719
# Saving image crop 3... label=Text conf=0.697
# Saving image crop 4... label=Text conf=0.607
# >>> Processing image: Screenshot 2025-09-18 152413.png
#
# 0: 928x1024 1 Picture, 5140.3ms
# Speed: 11.8ms preprocess, 5140.3ms inference, 15.8ms postprocess per image at shape (1, 3, 928, 1024)
# Total crops: 1
# Saving image crop 0... label=Picture conf=0.727
# >>> Processing image: Screenshot 2025-09-18 154837.png
#
# 0: 416x1024 1 Page-header, 1 Text, 2597.0ms
# Speed: 4.0ms preprocess, 2597.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 1024)
# Total crops: 2
# Saving image crop 0... label=Page-header conf=0.519
# Saving image crop 1... label=Text conf=0.591
# >>> Processing image: Screenshot 2025-09-18 171209.png
#
# 0: 800x1024 1 List-item, 9 Texts, 4945.6ms
# Speed: 19.7ms preprocess, 4945.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 1024)
# Total crops: 10
# Saving image crop 0... label=List-item conf=0.515
# Saving image crop 1... label=Text conf=0.582
# Saving image crop 2... label=Text conf=0.568
# Saving image crop 3... label=Text conf=0.565
# Saving image crop 4... label=Text conf=0.551
# Saving image crop 5... label=Text conf=0.549
# Saving image crop 6... label=Text conf=0.535
# Saving image crop 7... label=Text conf=0.520
# Saving image crop 8... label=Text conf=0.514
# Saving image crop 9... label=Text conf=0.511
# >>> Processing image: Screenshot 2025-09-18 171250.png
#
# 0: 800x1024 5 Texts, 3969.6ms
# Speed: 16.1ms preprocess, 3969.6ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 1024)
# Total crops: 5
# Saving image crop 0... label=Text conf=0.614
# Saving image crop 1... label=Text conf=0.605
# Saving image crop 2... label=Text conf=0.531
# Saving image crop 3... label=Text conf=0.528
# Saving image crop 4... label=Text conf=0.527
# >>> Processing image: Screenshot 2025-09-18 171846.png
#
# 0: 576x1024 1 Section-header, 3 Texts, 2752.4ms
# Speed: 11.1ms preprocess, 2752.4ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 1024)
# Total crops: 4
# Saving image crop 0... label=Section-header conf=0.532
# Saving image crop 1... label=Text conf=0.741
# Saving image crop 2... label=Text conf=0.659
# Saving image crop 3... label=Text conf=0.641
# >>> Processing image: Screenshot 2025-09-19 125707.png
#
# 0: 800x1024 (no detections), 4289.3ms
# Speed: 9.9ms preprocess, 4289.3ms inference, 0.0ms postprocess per image at shape (1, 3, 800, 1024)
# Total crops: 0
# >>> Processing image: Screenshot 2025-09-19 162813.png
#
# 0: 672x1024 1 Picture, 3380.6ms
# Speed: 12.0ms preprocess, 3380.6ms inference, 0.0ms postprocess per image at shape (1, 3, 672, 1024)
# Total crops: 1
# Saving image crop 0... label=Picture conf=0.529
# >>> Processing image: Screenshot 2025-09-19 165015.png
#
# 0: 1024x544 (no detections), 2638.5ms
# Speed: 12.0ms preprocess, 2638.5ms inference, 3.4ms postprocess per image at shape (1, 3, 1024, 544)
# Total crops: 0
# >>> Processing image: Screenshot 2025-09-19 170019.png
#
# 0: 416x1024 1 Picture, 1883.9ms
# Speed: 7.7ms preprocess, 1883.9ms inference, 0.0ms postprocess per image at shape (1, 3, 416, 1024)
# Total crops: 1
# Saving image crop 0... label=Picture conf=0.833
# >>> Processing image: Screenshot 2025-09-19 174221.png
#
# 0: 256x1024 1 Picture, 1101.1ms
# Speed: 10.6ms preprocess, 1101.1ms inference, 0.0ms postprocess per image at shape (1, 3, 256, 1024)
# Total crops: 1
# Saving image crop 0... label=Picture conf=0.820
# >>> Processing image: Screenshot 2025-09-21 203759.png
#
# 0: 576x1024 (no detections), 2733.7ms
# Speed: 8.4ms preprocess, 2733.7ms inference, 0.0ms postprocess per image at shape (1, 3, 576, 1024)
# Total crops: 0
# >>> Processing image: Screenshot 2025-09-22 012156.png
#
# 0: 736x1024 (no detections), 3700.9ms
# Speed: 0.0ms preprocess, 3700.9ms inference, 0.0ms postprocess per image at shape (1, 3, 736, 1024)
# Total crops: 0
# >>> Processing image: Screenshot 2025-09-22 125933.png
#
# 0: 896x1024 8 List-items, 1 Page-footer, 1 Section-header, 3 Texts, 5041.6ms
# Speed: 21.2ms preprocess, 5041.6ms inference, 0.0ms postprocess per image at shape (1, 3, 896, 1024)
# Total crops: 13
# Saving image crop 0... label=List-item conf=0.732
# Saving image crop 1... label=List-item conf=0.732
# Saving image crop 2... label=List-item conf=0.722
# Saving image crop 3... label=List-item conf=0.714
# Saving image crop 4... label=List-item conf=0.714
# Saving image crop 5... label=List-item conf=0.619
# Saving image crop 6... label=List-item conf=0.607
# Saving image crop 7... label=List-item conf=0.602
# Saving image crop 8... label=Section-header conf=0.557
# Saving image crop 9... label=Page-footer conf=0.652
# Saving image crop 10... label=Text conf=0.684
# Saving image crop 11... label=Text conf=0.594
# Saving image crop 12... label=Text conf=0.593
